# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
merged_data = pd.read_csv('DATA/MERGED_DATA.csv')

# %%
merged_data.describe()
# Out:
#         VIX_Close     BTC_Close   cpu_index  Emission intensity, gCO2e/kWh  \
# count  104.000000    104.000000  104.000000                     104.000000
# mean    18.999423  13606.673355  173.027412                     520.390791
# std      7.371747  16018.276123   72.400895                      40.033152
# min      9.510000    217.464005   49.125345                     360.781464
# 25%     13.667500    909.229981  107.826413                     506.711362
# 50%     16.910000   7675.034912  170.554106                     529.822110
# 75%     21.415000  19850.985840  222.372027                     540.256633
# max     53.540001  61318.957031  411.288806                     594.519817
#
#        Monthly consumption, TWh  Cumulative consumption, TWh
# count                104.000000                   104.000000
# mean                   4.018437                   126.968918
# std                    3.121214                   128.344552
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           104 non-null    object
#  1   VIX_Close                      104 non-null    float64
#  2   BTC_Close                      104 non-null    float64
#  3   cpu_index                      104 non-null    float64
#  4   Emission intensity, gCO2e/kWh  104 non-null    float64
#  5   Monthly consumption, TWh       104 non-null    float64
#  6   Cumulative consumption, TWh    104 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 5.8+ KB

# %% [markdown]
# # Regression plot for BTC and CPU

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='cpu_index', y='BTC_Close', data=merged_data, scatter_kws={'s': 10})
plt.xlabel('CPU Index')
plt.ylabel('Bitcoin Close Price')
plt.title('Regression Plot of Bitcoin Close Price vs CPU Index')
plt.show()

# %% [markdown]
# # Regression plot for BTC and VIX

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='VIX_Close', y='BTC_Close', data=merged_data, scatter_kws={'s': 10})
plt.xlabel('VIX Close')
plt.ylabel('Bitcoin Close Price')
plt.title('Regression Plot of Bitcoin Close Price vs VIX')
plt.show()

# %% [markdown]
# # Regression plot for BTC and Monthly consumption, TWh

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Monthly consumption, TWh', y='BTC_Close', data=merged_data, scatter_kws={'s': 10})
plt.xlabel('Monthly consumption, TWh')
plt.ylabel('Bitcoin Close Price')
plt.title('Regression Plot of Bitcoin Close Price vs Monthly consumption, TWh')
plt.show()

# %% [markdown]
# # Regression plot for BTC and Emission intensity, gCO2e/kWh

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Emission intensity, gCO2e/kWh', y='BTC_Close', data=merged_data, scatter_kws={'s': 10})
plt.xlabel('Emission intensity, gCO2e/kWh')
plt.ylabel('Bitcoin Close Price')
plt.title('Regression Plot of Bitcoin Close Price vs Emission intensity, gCO2e/kWh')
plt.show()
